# %%
import numpy as np
from scipy import sparse

# %%
A = sparse.lil_matrix((1000, 1000))
print(A)
# Out:
# <List of Lists sparse matrix of dtype 'float64'
# 	with 0 stored elements and shape (1000, 1000)>

# %%
A[0,:100] = np.random.rand(100)
A[1,100:200] = A[0,:100]
A.setdiag(np.random.rand(1000))
print(A)
# Out:
# <List of Lists sparse matrix of dtype 'float64'
# 	with 1199 stored elements and shape (1000, 1000)>
#   Coords	Values
#   (0, 0)	0.3161168709865809
#   (0, 1)	0.24195738162321045
#   (0, 2)	0.05109409750048244
#   (0, 3)	0.8482076353114482
#   (0, 4)	0.1449432468091827
#   (0, 5)	0.24158606461754495
#   (0, 6)	0.9030099467883022
#   (0, 7)	0.0755825371882426
#   (0, 8)	0.8143320012188595
#   (0, 9)	0.8174355490885109
#   (0, 10)	0.8724346747223236
#   (0, 11)	0.09406344065832206
#   (0, 12)	0.5135921956896171
#   (0, 13)	0.17727901062681595
#   (0, 14)	0.6520027974037528
#   (0, 15)	0.4641140865286276
#   (0, 16)	0.05573935004474251
#   (0, 17)	0.5828733679248975
#   (0, 18)	0.45690251181343466
#   (0, 19)	0.876391380200208
#   (0, 20)	0.287643975101444
#   (0, 21)	0.22962890869495878
#   (0, 22)	0.42717958194413863
#   (0, 23)	0.3590680048584046
#   (0, 24)	0.7942848348234406
#   :	:
#   (975, 975)	0.5882702856823209
#   (976, 976)	0.7386154349595231
#   (977, 977)	0.6295570327471441
#   (978, 978)	0.7667622493885621
#   (979, 979)	0.07709208219180519
#   (980, 980)	0.3460910209661028
#   (981, 981)	0.05397567069267273
#   (982, 982)	0.2663325585004461
#   (983, 983)	0.16566152682861734
#   (984, 984)	0.3292545591893269
#   (985, 985)	0.2644578020411309
#   (986, 986)	0.845761320798894
#   (987, 987)	0.9333108844454704
#   (988, 988)	0.9438407859946941
#   (989, 989)	0.6820277666850165
#   (990, 990)	0.5988438743770468
#   (991, 991)	0.31740994286616053
#   (992, 992)	0.7725735622290888
#   (993, 993)	0.05701717274168239
#   (994, 994)	0.9710655018866126
#   (995, 995)	0.8178116624452565
#   (996, 996)	0.223419231060888
#   (997, 997)	0.2961874828269583
#   (998, 998)	0.9548081506572228
#   (999, 999)	0.06650491961217975
